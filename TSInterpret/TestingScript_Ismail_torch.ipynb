# %%
from data import load_data
import sklearn
import pickle
import numpy as np 
import torch 
from ClassificationModels.CNN_T import ResNetBaseline, get_all_preds, fit, UCRDataset
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import pandas as pd
import os 
from tslearn.datasets import UCR_UEA_datasets

# %% [markdown]
# # Parameters

# %%
dataset='BasicMotions'#'GunPoint'

# %% [markdown]
# # Load Data

# %%
#TODO include OneHot Encoding Options
#train_x,test_x, train_y, test_y = load_data.load_basic_dataset(dataset,scaling=None,mode='feat',cwd='/media/jacqueline/Data/UCRArchive_2018/')

# %%
X_train,y_train, X_test, y_test=UCR_UEA_datasets().load_dataset(dataset)
train_x=X_train.reshape(-1,X_train.shape[-1],X_train.shape[-2])
test_x=X_test.reshape(-1,X_train.shape[-1],X_train.shape[-2])
train_y = y_train
test_y=y_test

# %%
print(test_y.shape)
# Out:
# (40,)

# %%
#enc1=sklearn.preprocessing.OneHotEncoder(sparse=False).fit(np.vstack((train_y.reshape(-1,1),test_y.reshape(-1,1))))
#pickle.dump(enc1,open(f'./ClassificationModels/models/{dataset}/OneHotEncoder.pkl','wb'))
enc1=pickle.load(open(f'./ClassificationModels/models/{dataset}/OneHotEncoder.pkl','rb'))
train_y=enc1.transform(train_y.reshape(-1,1))
test_y=enc1.transform(test_y.reshape(-1,1))

# %% [markdown]
# # Model Training

# %%
n_pred_classes =train_y.shape[1]
train_dataset = UCRDataset(train_x.astype(np.float64),train_y.astype(np.int64))
test_dataset = UCRDataset(test_x.astype(np.float64),test_y.astype(np.int64))
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=16,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=1,shuffle=False)
model = ResNetBaseline(in_channels=6, num_pred_classes=n_pred_classes)
fit(model,train_loader,test_loader)
if dataset in os.listdir('./ClassificationModels/models/'):
    print('Folder exists')
else: 
    os.mkdir(f'./ClassificationModels/models/{dataset}')
torch.save(model.state_dict(), f'./ClassificationModels/models/{dataset}/ResNet')
model.load_state_dict(torch.load(f'./ClassificationModels/models/{dataset}/ResNet'))
model.eval()

test_preds, ground_truth = get_all_preds(model, test_loader)
ground_truth=np.argmax(ground_truth,axis=1)

sns.set(rc={'figure.figsize':(5,4)})
heatmap=confusion_matrix(ground_truth, test_preds)
sns.heatmap(heatmap, annot=True)
plt.savefig(f'./ClassificationModels/models/{dataset}/ResNet_confusion_matrix.png')
plt.close()
acc= accuracy_score(ground_truth, test_preds)
a = classification_report(ground_truth, test_preds, output_dict=True)
dataframe = pd.DataFrame.from_dict(a)
dataframe.to_csv(f'./ClassificationModels/models/{dataset}/classification_report.csv', index = False)
# Out:
# Epoch: 1, Train loss: 1.22, Val loss: 1.238
# Epoch: 2, Train loss: 1.118, Val loss: 1.086
# Epoch: 3, Train loss: 1.054, Val loss: 0.999
# Epoch: 4, Train loss: 0.985, Val loss: 0.887
# Epoch: 5, Train loss: 0.844, Val loss: 0.787
# Epoch: 6, Train loss: 0.703, Val loss: 0.582
# Epoch: 7, Train loss: 0.496, Val loss: 0.415
# Epoch: 8, Train loss: 0.254, Val loss: 0.209
# Epoch: 9, Train loss: 0.106, Val loss: 0.077
# Epoch: 10, Train loss: 0.035, Val loss: 0.106
# Epoch: 11, Train loss: 0.004, Val loss: 0.273
# Epoch: 68, Train loss: 0.0, Val loss: 0.146
# Epoch: 69, Train loss: 0.0, Val loss: 0.146
# Epoch: 70, Train loss: 0.0, Val loss: 0.147
# Epoch: 71, Train loss: 0.0, Val loss: 0.147
# Epoch: 72, Train loss: 0.0, Val loss: 0.148
# Epoch: 73, Train loss: 0.0, Val loss: 0.148
# Epoch: 74, Train loss: 0.0, Val loss: 0.148
# Epoch: 75, Train loss: 0.0, Val loss: 0.149
# Epoch: 76, Train loss: 0.0, Val loss: 0.149
# Epoch: 77, Train loss: 0.0, Val loss: 0.15
# Epoch: 78, Train loss: 0.0, Val loss: 0.151
# Epoch: 79, Train loss: 0.0, Val loss: 0.151
# Epoch: 80, Train loss: 0.0, Val loss: 0.151
# Epoch: 81, Train loss: 0.0, Val loss: 0.151
# Epoch: 82, Train loss: 0.0, Val loss: 0.151
# Epoch: 83, Train loss: 0.0, Val loss: 0.151
# Epoch: 84, Train loss: 0.0, Val loss: 0.152
# Epoch: 85, Train loss: 0.0, Val loss: 0.152
# Epoch: 86, Train loss: 0.0, Val loss: 0.152
# Epoch: 87, Train loss: 0.0, Val loss: 0.152
# Epoch: 88, Train loss: 0.0, Val loss: 0.152
# Epoch: 89, Train loss: 0.0, Val loss: 0.151
# Epoch: 90, Train loss: 0.0, Val loss: 0.151
# Epoch: 91, Train loss: 0.0, Val loss: 0.151
# Epoch: 92, Train loss: 0.0, Val loss: 0.152
# Epoch: 93, Train loss: 0.0, Val loss: 0.152
# Epoch: 94, Train loss: 0.0, Val loss: 0.152
# Epoch: 95, Train loss: 0.0, Val loss: 0.153
# Epoch: 96, Train loss: 0.0, Val loss: 0.153
# Epoch: 97, Train loss: 0.0, Val loss: 0.153
# Epoch: 98, Train loss: 0.0, Val loss: 0.153
# Epoch: 99, Train loss: 0.0, Val loss: 0.153
# Epoch: 100, Train loss: 0.0, Val loss: 0.153
# Epoch: 101, Train loss: 0.0, Val loss: 0.154
# Epoch: 102, Train loss: 0.0, Val loss: 0.154
# Epoch: 103, Train loss: 0.0, Val loss: 0.154
# Epoch: 104, Train loss: 0.0, Val loss: 0.154
# Epoch: 105, Train loss: 0.0, Val loss: 0.154
# Epoch: 106, Train loss: 0.0, Val loss: 0.154
# Epoch: 107, Train loss: 0.0, Val loss: 0.154
# Epoch: 108, Train loss: 0.0, Val loss: 0.154
# Epoch: 109, Train loss: 0.0, Val loss: 0.154
# Early stopping!
# Folder exists

# %% [markdown]
# # Explanation Algo

# %%
from InterpretabilityModels.IsmailEtAl.SaliencyMethods_PT import Saliency_PT
int_mod=Saliency_PT(model, train_x.shape[-1],train_x.shape[-2], method='GS',mode='feat')

# %%
item = np.array([test_x[0,:,:]])
label = int(np.argmax(test_y[0]))

# %%
exp=int_mod.explain(item,labels=label,TSR = True)
# Out:
# feature mask (100, 6)
# time mask (100, 6)
# TSR is set true
# sequence length 100
# inpu size 6
# Else
# (1, 6, 100)
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])
# torch.Size([1, 6, 100])

# %%
int_mod.plot(np.array([test_x[0,:,:]]),exp)
# Out:
# feat
# NOT Time mode

# %%
int_mod.plot(np.array([test_x[0,:,:]]),exp, heatmap = True)
# Out:
# feat
# NOT Time mode
