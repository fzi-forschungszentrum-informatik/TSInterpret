# %% [markdown]
# # SETS
#
# A counterfactual explanation, originally introduced to machine learning by [1], answers the question "what if" by building counterexamples. Based on an input instance $x$, the goal is to find a counterfactual $x^{cf}$ close to the original instance $x$ but differently classified $y \neq y^{cf}$ by a predictor $f$. The intention is to visualize boundary cases. Further research has shown that counterfactual explanations are easy to understand for humans because they are intuitive  to human thinking by showing counterexamples.
#
# Shapelet-based Temporal Association Rule Mining for Multivariate Time Series Classification developed by Bahri et al. [1] builds counterfactuals in multivariate setting by perturbing the features of a time series with the help of a shapelet algorithm. Hereby they extract the most prominent class shapelets using an adaption of the shapelet transform algorithm of [2] implemented in sktime. The algorithm is adapted to multivariate timeseries analysis, treating each dimension as a univariate timeseries and information gain. The algorithm imputes the shapelets based on prior observed occcurences and shapelet quality. If a single shapelet does not cause a counterfactual prediction, more perturbations in other dimensions or other parts of the timeseries are performed.
#
#
# <img src="./docs/Notebooks/SETS_CF.png" alt="Visualization of SETS_CF" style="width: 800px;" />
#
#
#
# Visualization of SETS from the original paper [1]; The code in TSInterpret is based on the authors <a href='https://github.com/omarbahri/SETS'>implementation </a>.
#
# [1] Omar Bahri and Soukaina Filali Boubrahimi and Shah Muhammad Hamdi.Shapelet-Based Counterfactual Explanations for Multivariate Time Series. 2022 ACM SIGKDD Workshop on Mining and Learning from Time Series. arXiv:2208.10462 URL:https://arxiv.org/abs/2208.10462 (visited on 2023-12-04)
#
#
# [2] Hills, Jon and Lines, Jason and Baranauskas, Edgaras and Mapp, James and Bagnall, Anthony. Classification of time series by shapelet transformation. Data Mining and Knowledge Discovery. Harv. JL & Tech. 31 (2017): 841.

# %%
import numpy as np
from tslearn.datasets import UCR_UEA_datasets
import warnings
import tensorflow.keras as keras

warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From c:\Users\ss281\AppData\Local\anaconda3\envs\tsinterpret2\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load Data and Model
# - Load Data and reshape the data to fit a 1D-Conv Convolutional Neural Network (CNN). Note that the input for a 1D-Conv CNN hat the shape (batch, timesteps, features).
# - Load Model with Pretrained Weigths.

# %%
data = UCR_UEA_datasets().load_dataset("ECG200")

# %%
model = keras.models.load_model("./docs/Notebooks/best_model.hdf5")

# %% [markdown]
# ## Interpretability Algorithm
#
# Using a interpretability algorithm consists of 4 steps:
#
# 1. Load the Interpretability Method
# 2. Instaniate the Method with the desired Parameters
# 3. Call the explain Method
# 4. Plot the results
#
# ### 1. & 2. Loading & Initialization
#
# SETS works on all models returning a probability function. The Initialization takes the following arguments:
#
#     `model`: The model to be explaines.
#     `data`: Tuple of Data and Labels.
#     `backend`: `PYT`, `SK`, or `TF`.
#     `mode`: second dimension is either `feat` or `time`.
#     `method`: Optimization Method either `brut` or `opt`.
#     `min_shapelet_len` : Value for min length of extracted shapelets
#     `max_shapelet_len`: Value for max length of extracted shapelets
#     `time_contract_in_mins_per_dim` : Max time for shapelet extraction per dimension
#     `initial_num_shapelets_per_case` : Initial number of shapelets per case.

# %% [markdown]
# ### For Univariate ECG200 Case

# %%
# %load_ext autoreload
# %autoreload 2

from TSInterpret.InterpretabilityModels.counterfactual.SETSCF import SETSCF

# Note: this is for demonstration purposes, time contract per minutes should be adjusted for better results! 

exp_model= SETSCF(model,
                  data,
                  backend='TF',
                  mode='time',         
                  min_shapelet_len=3,
                  max_shapelet_len=20,
                  time_contract_in_mins_per_dim=1,
                  initial_num_shapelets_per_case=10)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 3. Call the explain method.
#
# Prepeare the instance and the predicted label of the instance as parameters for the explain methods.
#
# - `item`: item to be explained

# %%
ts = 0
exp = exp_model.explain(ts, data[0][0])
# Out:
# 4/4 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
array, label=exp
print(label)
# Out:
# 0

# %%
array.shape
# Out:
# (1, 6, 100)

# %% [markdown]
# ### 4. Visualization
#
# All plot function take as input the item to be explained and the returned explanation. As as additonal option a figsize can be given.

# %%
exp_model.plot(
        data[2][ts],
        np.argmax(model(data[2])[ts]),
        array,
        label,
        vis_change=True,
        all_in_one=False,
        save_fig=None,
        figsize=(6.4, 4.8))

# %% [markdown]
# ### Multivariate Case

# %%
data = UCR_UEA_datasets().load_dataset("BasicMotions")
model = keras.models.load_model("./docs/Notebooks/best_model_bm.hdf5")

# %%
exp_model= SETSCF(model,
                  data,
                  backend='TF',
                  mode='time',         
                  min_shapelet_len=3,
                  max_shapelet_len=20,
                  time_contract_in_mins_per_dim=1,
                  initial_num_shapelets_per_case=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ss281\Desktop\Projects\TSInterpret\Sets_tensorflow.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> exp_model= SETSCF(model,
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>                   data,
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>                   backend='TF',
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a>                   mode='time',
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>                   min_shapelet_len=3,
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a>                   max_shapelet_len=20,
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a>                   time_contract_in_mins_per_dim=1,
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a>                   initial_num_shapelets_per_case=10)
#
# File c:\Users\ss281\Desktop\Projects\TSInterpret\TSInterpret\InterpretabilityModels\counterfactual\SETSCF.py:116, in SETSCF.__init__(self, model, data, backend, mode, min_shapelet_len, max_shapelet_len, time_contract_in_mins_per_dim, initial_num_shapelets_per_case, silent)
#     114 self.train_distances = get_shapelets_distances(self.transformer)
#     115 self.shapelets = get_shapelets(self.transformer)
# --> 116 self.scores = get_scores(self.transformer)
#     117 self.indicies = get_indices(self.transformer)
#     118 # Save distances for test
#
# File c:\Users\ss281\Desktop\Projects\TSInterpret\TSInterpret\InterpretabilityModels\counterfactual\SETS\utils.py:100, in get_scores(transformer)
#      97         dim_scores.append(shapelet.info_gain)
#      98     all_scores.append(dim_scores)
# --> 100 return np.asarray(np.asarray(all_scores))
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.

# %%
        self.shapelets = get_shapelets(self.transformer)
        self.scores = get_scores(self.transformer)
        self.indicies = get_indices(self.transformer)
        # Save distances for test
        self.test_x_new = transformer.transform(self.test_x_n)
        self.test_distances = get_shapelets_distances(transformer)
        (
            self.all_heat_maps,
            self.all_shapelets_class,
            self.all_shapelet_locations,
            self.all_shapelet_locations_test,
        ) = get_class_shapelets(
            self.trf_data,
            self.ts_len,
            self.shapelets,
            self.train_distances,
            self.test_distances

# %%
from TSInterpret.InterpretabilityModels.counterfactual.SETS.utils import (
    MultivariateTransformer,
    get_indices,
    get_scores,
    get_shapelets,
    get_shapelets_distances,
)
exp_model.scores = get_scores(exp_model.transformer)
exp_model.scores = get_indices(exp_model.transformer)
exp_model.test_distances = get_shapelets_distances(exp_model.transformer)

# %%
from TSInterpret.InterpretabilityModels.counterfactual.SETS.class_shapelets import get_class_shapelets
(
    exp_model.all_heat_maps,
    exp_model.all_shapelets_class,
    exp_model.all_shapelet_locations,
    exp_model.all_shapelet_locations_test,
) = get_class_shapelets(
    exp_model.trf_data,
    exp_model.ts_len,
    exp_model.shapelets,
    exp_model.train_distances,
    exp_model.test_distances,
)

# %%
ts = 0
exp = exp_model.explain(ts, data[0][0])
array, label=exp
print(label)
print(array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ss281\Desktop\Projects\TSInterpret\Sets_tensorflow.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> ts = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> exp = exp_model.explain(ts, data[0][0])
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> array, label=exp
#       <a href='vscode-notebook-cell:/c%3A/Users/ss281/Desktop/Projects/TSInterpret/Sets_tensorflow.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> print(label)
#
# File c:\Users\ss281\Desktop\Projects\TSInterpret\TSInterpret\InterpretabilityModels\counterfactual\SETSCF.py:147, in SETSCF.explain(self, ts_instance, x, orig_class, target)
#     134 def explain(
#     135     self, ts_instance, x: np.ndarray, orig_class: int = None, target: int = None
#     136 ) -> Tuple[np.ndarray, int]:
#     137     # x (np.array): The instance to explain. Shape : `mode = time` -> `(1,time, feat)` or `mode = time` -> `(1,feat, time)`
#     138     # target int: target class. If no target class is given, the class with the secon heighest classification probability is selected.
#     139     """
#     140     Calculates the Counterfactual according to Ates.
#     141     Arguments:
#    (...)
#     145
#     146     """
# --> 147     exp, label = sets_explain(
#     148         ts_instance,
#     149         self.model,
#     150         self.data,
#     151         self.ts_len,
#     152         self.shapelets,
#     153         self.all_shapelet_locations,
#     154         self.all_shapelet_locations_test,
#     155         self.all_shapelets_class,
#     156         self.all_heat_maps,
#     157         self.scores,
#     158     )
#     159     if exp is not None:
#     160         org_shape = x.shape
#
# File c:\Users\ss281\Desktop\Projects\TSInterpret\TSInterpret\InterpretabilityModels\counterfactual\SETS\sets.py:38, in sets_explain(instance_idx, model, data, ts_length, st_shapelets, all_shapelet_locations, all_shapelet_locations_test, all_shapelets_class, all_heat_maps, all_shapelets_scores)
#      36 shapelets_best_scores = []
#      37 for dim in range(len(st_shapelets)):
# ---> 38     shapelets_best_scores.append(max(all_shapelets_scores[dim]))
#      40 shapelets_best_scores = np.argsort(shapelets_best_scores)[::-1]
#      42 y_pred = model.predict(np.swapaxes(X_test, 1, 2))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# Additional Examples, e.g. for the use with LSTM or TF can be found <a href='https://github.com/JHoelli/TSInterpret/blob/main/docs/Notebooks'>here</a>.
